# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/rdataa.csv')
df
# Out:
#       N   P   K  Temperature  Moisture   PH  Humidity          Crops
# 0    78  35  44         33.8        32  5.1      46.0    Greenchilli
# 1    65  37  40         33.8        32  5.1      46.0    Greenchilli
# 2    71  54  16         33.8        34  5.1      46.0    Greenchilli
# 3    61  44  17         33.8        33  5.1      46.0    Greenchilli
# 4    80  43  16         33.8        34  5.1      46.0    Greenchilli
# ..   ..  ..  ..          ...       ...  ...       ...            ...
# 396  17  64  18         34.3        43  6.2      44.1  Custard Apple
# 397  35  71  17         34.3        42  6.2      44.1  Custard Apple
# 398  11  72  22         34.2        42  6.2      44.2  Custard Apple
# 399  20  60  22         34.3        43  6.2      44.1  Custard Apple
# 400  10  71  18         34.3        42  6.2      44.1  Custard Apple
#
# [401 rows x 8 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Crops']= le.fit_transform(df['Crops'])
df
# Out:
#       N   P   K  Temperature  Moisture   PH  Humidity  Crops
# 0    78  35  44         33.8        32  5.1      46.0      2
# 1    65  37  40         33.8        32  5.1      46.0      2
# 2    71  54  16         33.8        34  5.1      46.0      2
# 3    61  44  17         33.8        33  5.1      46.0      2
# 4    80  43  16         33.8        34  5.1      46.0      2
# ..   ..  ..  ..          ...       ...  ...       ...    ...
# 396  17  64  18         34.3        43  6.2      44.1      1
# 397  35  71  17         34.3        42  6.2      44.1      1
# 398  11  72  22         34.2        42  6.2      44.2      1
# 399  20  60  22         34.3        43  6.2      44.1      1
# 400  10  71  18         34.3        42  6.2      44.1      1
#
# [401 rows x 8 columns]

# %%
col_names = df.columns
col_names
# Out:
# Index(['N', 'P', 'K', 'Temperature', 'Moisture', 'PH', 'Humidity', 'Crops'], dtype='object')

# %%
df['Crops'].value_counts()
# Out:
# 1    41
# 2    40
# 7    40
# 5    40
# 3    40
# 9    40
# 8    40
# 0    40
# 6    40
# 4    40
# Name: Crops, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401 entries, 0 to 400
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            401 non-null    int64
#  1   P            401 non-null    int64
#  2   K            401 non-null    int64
#  3   Temperature  401 non-null    float64
#  4   Moisture     401 non-null    int64
#  5   PH           401 non-null    float64
#  6   Humidity     401 non-null    float64
#  7   Crops        401 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 25.2 KB

# %%
df.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# Temperature    0
# Moisture       0
# PH             0
# Humidity       0
# Crops          0
# dtype: int64

# %%
round(df.describe(),2)
# Out:
#             N       P       K  Temperature  Moisture      PH  Humidity   Crops
# count  401.00  401.00  401.00       401.00    401.00  401.00    401.00  401.00
# mean    40.01   62.75   35.07        34.08     56.53    5.98     45.15    4.49
# std     26.13   11.41   26.10         0.25     27.97    0.50      0.98    2.88
# min      0.00   35.00   15.00        33.70     31.00    5.10     43.60    0.00
# 25%     21.00   56.00   18.00        33.80     32.00    5.70     44.30    2.00
# 50%     34.00   63.00   22.00        34.20     40.00    5.90     44.90    4.00
# 75%     60.00   72.00   44.00        34.30     89.00    6.20     45.80    7.00
# max    100.00   80.00   85.00        34.40     99.00    6.80     48.30    9.00

# %%
#feature vector and target variable
X = df.drop(['Crops'], axis=1)

# %%
y = df['Crops']#target variable for prediction

# %%
#Split data into train and testing data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((320, 7), (81, 7))

# %%
cols = X_train.columns

# %%
from sklearn.preprocessing import StandardScaler #scale each feature by subracting mean
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
X_train.describe() #summary statistics
# Out:
#                   N             P             K   Temperature    Moisture  \
# count  3.200000e+02  3.200000e+02  3.200000e+02  3.200000e+02  320.000000
# mean   1.110223e-16  1.387779e-16  5.551115e-17 -1.629530e-14    0.000000
# std    1.001566e+00  1.001566e+00  1.001566e+00  1.001566e+00    1.001566
# min   -1.518230e+00 -2.526223e+00 -7.574162e-01 -1.536221e+00   -0.902282
# 25%   -7.384633e-01 -6.489457e-01 -6.017494e-01 -1.133608e+00   -0.866548
# 50%   -3.095917e-01  6.620755e-02 -4.849993e-01  4.768450e-01   -0.616411
# 75%    7.820815e-01  7.813608e-01 -3.682493e-01  8.794582e-01    1.170287
# max    2.341615e+00  1.496514e+00  1.966753e+00  1.282071e+00    1.527626
#
#                  PH      Humidity
# count  3.200000e+02  3.200000e+02
# mean  -6.494805e-16 -1.515454e-15
# std    1.001566e+00  1.001566e+00
# min   -1.811593e+00 -1.538076e+00
# 25%   -6.150815e-01 -8.312050e-01
# 50%   -2.162445e-01 -3.262969e-01
# 75%    3.820111e-01  5.825378e-01
# ...

# %% [markdown]
# **SUPPORT VECTOR MACHINE**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score,recall_score,f1_score,classification_report

# %%
svc=SVC(C=1000.0)#classify training points correctly

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(C=1000.0)

# %%
y_pred=svc.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00        13
#            3       1.00      1.00      1.00        12
#            4       1.00      1.00      1.00         7
#            5       0.80      1.00      0.89         4
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00        10
#            8       1.00      1.00      1.00         8
#            9       1.00      0.89      0.94         9
#
#     accuracy                           0.99        81
#    macro avg       0.98      0.99      0.98        81
# weighted avg       0.99      0.99      0.99        81

# %%
precision = precision_score(y_test, y_pred, average='macro')
print("Precision:{0:0.4f}".format( precision))
recall = recall_score(y_test, y_pred, average='macro')#change the average parameter as needed
print("Recall:{0:0.4f}".format( recall))
f1 = f1_score(y_test, y_pred, average='macro')#calculates metrics for each label
print("F1-score:{0:0.4f}".format( f1))
# Out:
# Precision:0.9800
# Recall:0.9889
# F1-score:0.9830

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score,f1_score
from sklearn.metrics import recall_score,classification_report
# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors = 3)#no of neighbor vote for target value
# Fit the classifier to the data
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(X_test)
report = classification_report(y_test, y_pred)
print("classification report")
print(report)
precision = precision_score(y_test, y_pred, average='macro')
print("Precision:{0:0.4f}".format( precision))
recall = recall_score(y_test, y_pred, average='macro')
print("Recall:{0:0.4f}".format( recall))
f1 = f1_score(y_test, y_pred, average='macro')
print("F1-score:{0:0.4f}".format( f1))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00        13
#            3       0.91      0.83      0.87        12
#            4       1.00      1.00      1.00         7
#            5       0.80      1.00      0.89         4
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00        10
#            8       1.00      1.00      1.00         8
#            9       0.78      0.78      0.78         9
#
#     accuracy                           0.95        81
#    macro avg       0.95      0.96      0.95        81
# weighted avg       0.95      0.95      0.95        81
#
# Precision:0.9487
# Recall:0.9611
# F1-score:0.9536

# %% [markdown]
# **DECISION TREE**

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
report = classification_report(y_test, y_pred)
print("classification report")
print(report)
precision = precision_score(y_test, y_pred, average='macro')
print("Precision:{0:0.4f}".format( precision))
recall = recall_score(y_test, y_pred, average='macro')
print("Recall:{0:0.4f}".format( recall))
f1 = f1_score(y_test, y_pred, average='macro')
print("F1-score:{0:0.4f}".format( f1))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        43
#            1       0.97      0.99      0.98        71
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
#
# Precision:0.9742
# Recall:0.9697
# F1-score:0.9719

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Create logistic regression object
logreg = LogisticRegression(max_iter=1000)# solve

# Train the model using the training sets
logreg.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = logreg.predict(X_test)

# %%
print("classification report")
print(report)
precision = precision_score(y_test, y_pred, average='macro')
print("Precision:{0:0.4f}".format( precision))
recall = recall_score(y_test, y_pred, average='macro')
print("Recall:{0:0.4f}".format( recall))
f1 = f1_score(y_test, y_pred, average='macro')
print("F1-score:{0:0.4f}".format( f1))
# Out:
# classification report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00        13
#            3       0.91      0.83      0.87        12
#            4       1.00      1.00      1.00         7
#            5       0.80      1.00      0.89         4
#            6       1.00      1.00      1.00         8
#            7       1.00      1.00      1.00        10
#            8       1.00      1.00      1.00         8
#            9       0.78      0.78      0.78         9
#
#     accuracy                           0.95        81
#    macro avg       0.95      0.96      0.95        81
# weighted avg       0.95      0.95      0.95        81
#
# Precision:1.0000
# Recall:1.0000
# F1-score:1.0000
